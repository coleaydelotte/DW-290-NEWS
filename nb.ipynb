# %%
import pandas as pd

# %%
data = pd.read_csv('all_articles_summary.csv')
data.head()
# Out:
#                                        UUID  \
# 0  806ba3371a092e3ad8c182947177a3626953419a
# 1  806ba3371a092e3ad8c182947177a3626953419a
# 2  806ba3371a092e3ad8c182947177a3626953419a
# 3  806ba3371a092e3ad8c182947177a3626953419a
# 4  806ba3371a092e3ad8c182947177a3626953419a
#
#                                                  URL         Author Title  \
# 0  https://www.thegatewaypundit.com/2025/02/runup...  jimmyslippers   NaN
# 1  https://www.thegatewaypundit.com/2025/02/runup...  jimmyslippers   NaN
# 2  https://www.thegatewaypundit.com/2025/02/runup...  jimmyslippers   NaN
# 3  https://www.thegatewaypundit.com/2025/02/runup...  jimmyslippers   NaN
# 4  https://www.thegatewaypundit.com/2025/02/runup...  jimmyslippers   NaN
#
#                        Published Language  Rating  \
# 0  2025-02-09T18:28:26.280+02:00  english     NaN
# 1  2025-02-09T18:28:26.280+02:00  english     NaN
# 2  2025-02-09T18:28:26.280+02:00  english     NaN
# ...

# %%
data.shape
# Out:
# (49000, 20)

# %%
# Number of null values in the "Title" column
data["Title"].isnull().sum()
# Out:
# 14429
